# %%
# !pip install requests beautifulsoup4 trafilatura
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: trafilatura in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.9)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: courlan>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from trafilatura) (3.0.2)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from trafilatura) (5.4.0)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura) (2.17.0)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura) (0.13.1)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from htmldate>=1.9.2->trafilatura) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /usr/local/lib/python3.11/dist-packages (from htmldate>=1.9.2->trafilatura) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura) (5.3.1)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.11/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.9.0.post0->htmldate>=1.9.2->trafilatura) (1.17.0)

# %%
import trafilatura

def scrape_clean_text(url):
    downloaded = trafilatura.fetch_url(url)
    if downloaded:
        return trafilatura.extract(downloaded, include_comments=False, include_tables=False)
    else:
        return None

# %%
url = "https://docs.utilihive.io/utilihive-integration/"
content = scrape_clean_text(url)

if content:
    print(content[:1000])
else:
    print("❌ Failed to fetch or parse.")
# Out:
# Utilihive Integration
# Learn about Utilihive
# -
# See what’s available in the Utilihive platform.
# Start Developing
# -
# Get up and running with the tools to write flow configurations.
# -
# Jump into the detailed developer guides.
# -
# Ready to deploy a flow? Try the SDK Deployer.
# Explore the Console
# -
# Monitor your data with Heartbeat.
# -
# Utility-specific needs? Check out the Utilihive Accelerators like Datalake and Ghostwriter.

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin

def scrape_site(url, max_pages=5):
    visited = set()
    to_visit = [url]
    contents = []

    while to_visit and len(visited) < max_pages:
        current_url = to_visit.pop(0)
        if current_url in visited:
            continue

        try:
            response = requests.get(current_url, timeout=10)
            soup = BeautifulSoup(response.text, "html.parser")
            main_text = trafilatura.extract(response.text)

            if main_text:
                contents.append({
                    "url": current_url,
                    "text": main_text
                })

            visited.add(current_url)

            # Get internal links
            for a in soup.find_all("a", href=True):
                next_url = urljoin(url, a['href'])
                if url in next_url and next_url not in visited and next_url not in to_visit:
                    to_visit.append(next_url)

        except Exception as e:
            print(f"⚠️ Skipped {current_url}: {e}")

    return contents

# %%
pages = scrape_site("https://docs.utilihive.io/utilihive-integration/", max_pages=1000)
print(f"Scraped {len(pages)} pages.")
# print(pages[0]['text'][:1000])
# Out:
# Scraped 668 pages.

# %%
for page in pages:
    print(page['url'])
    # print(page['text'][:1000])
    print()
# Out:
# https://docs.utilihive.io/utilihive-integration/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/platform/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/flows/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/flow-server/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/resources/
#
# https://docs.utilihive.io/utilihive-integration/core-concepts/console/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/introduction/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/installation/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/advanced-setup/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/kotlin/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/first-flow/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/examples/e01/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/examples/e02/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/examples/e03/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/examples/e04/
#
# https://docs.utilihive.io/utilihive-integration/getting-started/examples/e05/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/flow-specs/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/functional-tests/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/unit-tests/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/deployment-verification-tests/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/considerations/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/aggregate/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/archive-lookup/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/compress/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/consume-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/db-statement/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/decompress/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/delete-from-stash/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/distribute/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/filter/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/from-base64/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/group/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/handoff/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/hash/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/increment-counter/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/list-objects-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/load-certificate/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/lookup-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/lookup-from-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/lookup-from-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/map/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/move-aws-s3-object/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/parse-csv/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/parse-excel/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/parse-hierarchical-csv/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/read-files/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-habitat/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-jms/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-kafka/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-opc-ua/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/receive-from-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/rest-api/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/rest-request/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/resubmit/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/resume-message/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/save-to-stash/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/schedule/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/scheduled-handoff/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-event-hubs/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-jms/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-kafka/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/send-to-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/set-exchange-property/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/set-payload/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/sign/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/soap-api/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/soap-request/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/split/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/suspend-message/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/to-base64/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/validate/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/verify-signature/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/windowed-aggregation-handoff/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/write-files/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/write-to-arrow/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/write-to-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/write-to-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/write-to-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/circuit-breaker-strategy/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/data-format/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/external-system-details/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/inbound-transformation-strategy/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/message-logging-strategy/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/payload-archiving-strategy/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/strategies/processing-strategy/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/troubleshooting/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/payload-types/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/resource-registry/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/dynamic-tables/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/secrets/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/messaging/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/expressions/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/data-mapping/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/archiving/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/soap-tools/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/arrow-schema/
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/guides/avro-schema/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/deployer/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/advanced/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/on-prem-flow-server/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/management-api/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/heartbeat/
#
# https://docs.utilihive.io/utilihive-integration/deploying-managing-flows/flow-access/
#
# https://docs.utilihive.io/utilihive-integration/managing-platform/
#
# https://docs.utilihive.io/utilihive-integration/managing-platform/users/
#
# https://docs.utilihive.io/utilihive-integration/managing-platform/audits/
#
# https://docs.utilihive.io/utilihive-integration/managing-platform/beatbox/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/heartbeat/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/flow-list/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/flow-details/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/flow-traces/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/alerts/
#
# https://docs.utilihive.io/utilihive-integration/monitoring-reporting/reporting/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/overview/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/data-models/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/api/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/message-interface/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/persistence/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/datalake/self-service-analytics/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/ghostwriter/simulations/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/ghostwriter/ecosystems/
#
# https://docs.utilihive.io/utilihive-integration/accelerators/ghostwriter/profiles/
#
# https://docs.utilihive.io/utilihive-integration/#learn-about-utilihive
#
# https://docs.utilihive.io/utilihive-integration/#start-developing
#
# https://docs.utilihive.io/utilihive-integration/#explore-the-console
#
# https://docs.utilihive.io/utilihive-integration/platform/
#
# https://docs.utilihive.io/utilihive-integration/flows/
#
# https://docs.utilihive.io/utilihive-integration/flow-server/
#
# https://docs.utilihive.io/utilihive-integration/resources/
#
# https://docs.utilihive.io/utilihive-integration/console/
#
# https://docs.utilihive.io/utilihive-integration/#core-components
#
# https://docs.utilihive.io/utilihive-integration/#utilihive-ipaas
#
# https://docs.utilihive.io/utilihive-integration/#utilihive-console
#
# https://docs.utilihive.io/utilihive-integration/#utilihive-accelerators
#
# https://docs.utilihive.io/utilihive-integration/#what-is-a-flow
#
# https://docs.utilihive.io/utilihive-integration/#flow-configurations
#
# https://docs.utilihive.io/utilihive-integration/#processors
#
# https://docs.utilihive.io/utilihive-integration/#message-flow-control
#
# https://docs.utilihive.io/utilihive-integration/#reliability
#
# https://docs.utilihive.io/utilihive-integration/#example-use-cases
#
# https://docs.utilihive.io/utilihive-integration/#single-flow
#
# https://docs.utilihive.io/utilihive-integration/#multiple-flows
#
# https://docs.utilihive.io/utilihive-integration/#server-features
#
# https://docs.utilihive.io/utilihive-integration/#rest-api
#
# https://docs.utilihive.io/utilihive-integration/#heartbeat
#
# https://docs.utilihive.io/utilihive-integration/#server-variations
#
# https://docs.utilihive.io/utilihive-integration/#managing-platform:on-prem-flow-server.adoc
#
# https://docs.utilihive.io/utilihive-integration/#supported-data-types
#
# https://docs.utilihive.io/utilihive-integration/#datalake
#
# https://docs.utilihive.io/utilihive-integration/#ghostwriter
#
# https://docs.utilihive.io/utilihive-integration/introduction/
#
# https://docs.utilihive.io/utilihive-integration/installation/
#
# https://docs.utilihive.io/utilihive-integration/advanced-setup/
#
# https://docs.utilihive.io/utilihive-integration/kotlin/
#
# https://docs.utilihive.io/utilihive-integration/first-flow/
#
# https://docs.utilihive.io/utilihive-integration/examples/e01/
#
# https://docs.utilihive.io/utilihive-integration/examples/e02/
#
# https://docs.utilihive.io/utilihive-integration/examples/e03/
#
# https://docs.utilihive.io/utilihive-integration/examples/e04/
#
# https://docs.utilihive.io/utilihive-integration/examples/e05/
#
# https://docs.utilihive.io/utilihive-integration/#lowcode-dsl
#
# https://docs.utilihive.io/utilihive-integration/#sdk-components
#
# https://docs.utilihive.io/utilihive-integration/#local-server
#
# https://docs.utilihive.io/utilihive-integration/#testing-library
#
# https://docs.utilihive.io/utilihive-integration/#example-project
#
# https://docs.utilihive.io/utilihive-integration/#prerequisite-downloads
#
# https://docs.utilihive.io/utilihive-integration/#sdk-configuration
#
# https://docs.utilihive.io/utilihive-integration/#ge-vernova-artifactory-access
#
# https://docs.utilihive.io/utilihive-integration/#maven-configuration
#
# https://docs.utilihive.io/utilihive-integration/#project-setup
#
# https://docs.utilihive.io/utilihive-integration/#ensure-correct-repository-configuration-in-pom-xml
#
# https://docs.utilihive.io/utilihive-integration/#ensure-kotlin-2-1
#
# https://docs.utilihive.io/utilihive-integration/#manual-setup
#
# https://docs.utilihive.io/utilihive-integration/#downloading-sources
#
# https://docs.utilihive.io/utilihive-integration/#intellij-jsoniq-plugin
#
# https://docs.utilihive.io/utilihive-integration/#usage
#
# https://docs.utilihive.io/utilihive-integration/#application-overrides
#
# https://docs.utilihive.io/utilihive-integration/#ports
#
# https://docs.utilihive.io/utilihive-integration/#cleanup
#
# https://docs.utilihive.io/utilihive-integration/#jetbrains-academy-plugin
#
# https://docs.utilihive.io/utilihive-integration/#kotlin-for-flow-developers
#
# https://docs.utilihive.io/utilihive-integration/#kotlin-koans
#
# https://docs.utilihive.io/utilihive-integration/#reviewing-the-example-project
#
# https://docs.utilihive.io/utilihive-integration/#running-a-test
#
# https://docs.utilihive.io/utilihive-integration/#windows-notice
#
# https://docs.utilihive.io/utilihive-integration/#creating-the-flow
#
# https://docs.utilihive.io/utilihive-integration/#the-rest-resource
#
# https://docs.utilihive.io/utilihive-integration/#the-flow-specification
#
# https://docs.utilihive.io/utilihive-integration/#testing-the-flow
#
# https://docs.utilihive.io/utilihive-integration/#mocking-the-request
#
# https://docs.utilihive.io/utilihive-integration/#creating-the-resources
#
# https://docs.utilihive.io/utilihive-integration/#running-the-test
#
# https://docs.utilihive.io/utilihive-integration/#creating-the-flows
#
# https://docs.utilihive.io/utilihive-integration/#the-entry-point-flow
#
# https://docs.utilihive.io/utilihive-integration/#the-handoff-flows
#
# https://docs.utilihive.io/utilihive-integration/#testing-the-flows
#
# https://docs.utilihive.io/utilihive-integration/#the-test-context
#
# https://docs.utilihive.io/utilihive-integration/#the-test-assertions
#
# https://docs.utilihive.io/utilihive-integration/#creating-the-map
#
# https://docs.utilihive.io/utilihive-integration/#testing-the-map
#
# https://docs.utilihive.io/utilihive-integration/#soap-resources
#
# https://docs.utilihive.io/utilihive-integration/#flow-specification
#
# https://docs.utilihive.io/utilihive-integration/#transformation-logic
#
# https://docs.utilihive.io/utilihive-integration/flow-specs/
#
# https://docs.utilihive.io/utilihive-integration/functional-tests/
#
# https://docs.utilihive.io/utilihive-integration/unit-tests/
#
# https://docs.utilihive.io/utilihive-integration/deployment-verification-tests/
#
# https://docs.utilihive.io/utilihive-integration/considerations/
#
# https://docs.utilihive.io/utilihive-integration/processors/
#
# https://docs.utilihive.io/utilihive-integration/processors/aggregate/
#
# https://docs.utilihive.io/utilihive-integration/processors/archive-lookup/
#
# https://docs.utilihive.io/utilihive-integration/processors/compress/
#
# https://docs.utilihive.io/utilihive-integration/processors/consume-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/processors/db-statement/
#
# https://docs.utilihive.io/utilihive-integration/processors/decompress/
#
# https://docs.utilihive.io/utilihive-integration/processors/delete-from-stash/
#
# https://docs.utilihive.io/utilihive-integration/processors/distribute/
#
# https://docs.utilihive.io/utilihive-integration/processors/filter/
#
# https://docs.utilihive.io/utilihive-integration/processors/from-base64/
#
# https://docs.utilihive.io/utilihive-integration/processors/group/
#
# https://docs.utilihive.io/utilihive-integration/processors/handoff/
#
# https://docs.utilihive.io/utilihive-integration/processors/hash/
#
# https://docs.utilihive.io/utilihive-integration/processors/increment-counter/
#
# https://docs.utilihive.io/utilihive-integration/processors/list-objects-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/processors/load-certificate/
#
# https://docs.utilihive.io/utilihive-integration/processors/lookup-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/processors/lookup-from-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/processors/lookup-from-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/processors/map/
#
# https://docs.utilihive.io/utilihive-integration/processors/move-aws-s3-object/
#
# https://docs.utilihive.io/utilihive-integration/processors/parse-csv/
#
# https://docs.utilihive.io/utilihive-integration/processors/parse-excel/
#
# https://docs.utilihive.io/utilihive-integration/processors/parse-hierarchical-csv/
#
# https://docs.utilihive.io/utilihive-integration/processors/read-files/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-habitat/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-jms/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-kafka/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-opc-ua/
#
# https://docs.utilihive.io/utilihive-integration/processors/receive-from-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/processors/rest-api/
#
# https://docs.utilihive.io/utilihive-integration/processors/rest-request/
#
# https://docs.utilihive.io/utilihive-integration/processors/resubmit/
#
# https://docs.utilihive.io/utilihive-integration/processors/resume-message/
#
# https://docs.utilihive.io/utilihive-integration/processors/save-to-stash/
#
# https://docs.utilihive.io/utilihive-integration/processors/schedule/
#
# https://docs.utilihive.io/utilihive-integration/processors/scheduled-handoff/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-event-hubs/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-jms/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-kafka/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/processors/send-to-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/processors/set-exchange-property/
#
# https://docs.utilihive.io/utilihive-integration/processors/set-payload/
#
# https://docs.utilihive.io/utilihive-integration/processors/sign/
#
# https://docs.utilihive.io/utilihive-integration/processors/soap-api/
#
# https://docs.utilihive.io/utilihive-integration/processors/soap-request/
#
# https://docs.utilihive.io/utilihive-integration/processors/split/
#
# https://docs.utilihive.io/utilihive-integration/processors/suspend-message/
#
# https://docs.utilihive.io/utilihive-integration/processors/to-base64/
#
# https://docs.utilihive.io/utilihive-integration/processors/validate/
#
# https://docs.utilihive.io/utilihive-integration/processors/verify-signature/
#
# https://docs.utilihive.io/utilihive-integration/processors/windowed-aggregation-handoff/
#
# https://docs.utilihive.io/utilihive-integration/processors/write-files/
#
# https://docs.utilihive.io/utilihive-integration/processors/write-to-arrow/
#
# https://docs.utilihive.io/utilihive-integration/processors/write-to-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/processors/write-to-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/processors/write-to-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/strategies/circuit-breaker-strategy/
#
# https://docs.utilihive.io/utilihive-integration/strategies/data-format/
#
# https://docs.utilihive.io/utilihive-integration/strategies/external-system-details/
#
# https://docs.utilihive.io/utilihive-integration/strategies/inbound-transformation-strategy/
#
# https://docs.utilihive.io/utilihive-integration/strategies/message-logging-strategy/
#
# https://docs.utilihive.io/utilihive-integration/strategies/payload-archiving-strategy/
#
# https://docs.utilihive.io/utilihive-integration/strategies/processing-strategy/
#
# https://docs.utilihive.io/utilihive-integration/guides/troubleshooting/
#
# https://docs.utilihive.io/utilihive-integration/guides/payload-types/
#
# https://docs.utilihive.io/utilihive-integration/guides/resource-registry/
#
# https://docs.utilihive.io/utilihive-integration/guides/dynamic-tables/
#
# https://docs.utilihive.io/utilihive-integration/guides/secrets/
#
# https://docs.utilihive.io/utilihive-integration/guides/messaging/
#
# https://docs.utilihive.io/utilihive-integration/guides/expressions/
#
# https://docs.utilihive.io/utilihive-integration/guides/data-mapping/
#
# https://docs.utilihive.io/utilihive-integration/guides/archiving/
#
# https://docs.utilihive.io/utilihive-integration/guides/soap-tools/
#
# https://docs.utilihive.io/utilihive-integration/guides/arrow-schema/
#
# https://docs.utilihive.io/utilihive-integration/guides/avro-schema/
#
# https://docs.utilihive.io/utilihive-integration/#properties
#
# https://docs.utilihive.io/utilihive-integration/#exchange-patterns
#
# https://docs.utilihive.io/utilihive-integration/#groups
#
# https://docs.utilihive.io/utilihive-integration/#strategies
#
# https://docs.utilihive.io/utilihive-integration/#redelivery
#
# https://docs.utilihive.io/utilihive-integration/#dead-letter
#
# https://docs.utilihive.io/utilihive-integration/#catch-and-return
#
# https://docs.utilihive.io/utilihive-integration/#flow-pipeline-deployment
#
# https://docs.utilihive.io/utilihive-integration/#response-payload-archiving
#
# https://docs.utilihive.io/utilihive-integration/#basic-usage
#
# https://docs.utilihive.io/utilihive-integration/#test-context
#
# https://docs.utilihive.io/utilihive-integration/#resources
#
# https://docs.utilihive.io/utilihive-integration/#secrets
#
# https://docs.utilihive.io/utilihive-integration/#assertions
#
# https://docs.utilihive.io/utilihive-integration/#requests
#
# https://docs.utilihive.io/utilihive-integration/#rest
#
# https://docs.utilihive.io/utilihive-integration/#soap
#
# https://docs.utilihive.io/utilihive-integration/#mocking-requests
#
# https://docs.utilihive.io/utilihive-integration/#stubbing-libraries
#
# https://docs.utilihive.io/utilihive-integration/#tracing
#
# https://docs.utilihive.io/utilihive-integration/#logs
#
# https://docs.utilihive.io/utilihive-integration/#sdkdeploymentprovider
#
# https://docs.utilihive.io/utilihive-integration/#ephemeral-deployment-verification
#
# https://docs.utilihive.io/utilihive-integration/#default-setup
#
# https://docs.utilihive.io/utilihive-integration/#advanced-usage
#
# https://docs.utilihive.io/utilihive-integration/#customizing-the-sdkdeploymentprovider
#
# https://docs.utilihive.io/utilihive-integration/#sharing-custom-deployment-providers
#
# https://docs.utilihive.io/utilihive-integration/#setting-up-a-project-with-both-local-and-deployment-verification-tests
#
# https://docs.utilihive.io/utilihive-integration/#encrypting-test-secrets
#
# https://docs.utilihive.io/utilihive-integration/#generating-encrypted-values
#
# https://docs.utilihive.io/utilihive-integration/#storing-encryption-keys
#
# https://docs.utilihive.io/utilihive-integration/aggregate/
#
# https://docs.utilihive.io/utilihive-integration/archive-lookup/
#
# https://docs.utilihive.io/utilihive-integration/compress/
#
# https://docs.utilihive.io/utilihive-integration/consume-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/db-statement/
#
# https://docs.utilihive.io/utilihive-integration/decompress/
#
# https://docs.utilihive.io/utilihive-integration/delete-from-stash/
#
# https://docs.utilihive.io/utilihive-integration/distribute/
#
# https://docs.utilihive.io/utilihive-integration/filter/
#
# https://docs.utilihive.io/utilihive-integration/from-base64/
#
# https://docs.utilihive.io/utilihive-integration/group/
#
# https://docs.utilihive.io/utilihive-integration/handoff/
#
# https://docs.utilihive.io/utilihive-integration/hash/
#
# https://docs.utilihive.io/utilihive-integration/increment-counter/
#
# https://docs.utilihive.io/utilihive-integration/list-objects-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/load-certificate/
#
# https://docs.utilihive.io/utilihive-integration/lookup-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/lookup-from-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/lookup-from-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/map/
#
# https://docs.utilihive.io/utilihive-integration/move-aws-s3-object/
#
# https://docs.utilihive.io/utilihive-integration/parse-csv/
#
# https://docs.utilihive.io/utilihive-integration/parse-excel/
#
# https://docs.utilihive.io/utilihive-integration/parse-hierarchical-csv/
#
# https://docs.utilihive.io/utilihive-integration/read-files/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-habitat/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-jms/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-kafka/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-opc-ua/
#
# https://docs.utilihive.io/utilihive-integration/receive-from-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/rest-api/
#
# https://docs.utilihive.io/utilihive-integration/rest-request/
#
# https://docs.utilihive.io/utilihive-integration/resubmit/
#
# https://docs.utilihive.io/utilihive-integration/resume-message/
#
# https://docs.utilihive.io/utilihive-integration/save-to-stash/
#
# https://docs.utilihive.io/utilihive-integration/schedule/
#
# https://docs.utilihive.io/utilihive-integration/scheduled-handoff/
#
# https://docs.utilihive.io/utilihive-integration/send-to-event-hubs/
#
# https://docs.utilihive.io/utilihive-integration/send-to-google-pub-sub/
#
# https://docs.utilihive.io/utilihive-integration/send-to-jms/
#
# https://docs.utilihive.io/utilihive-integration/send-to-kafka/
#
# https://docs.utilihive.io/utilihive-integration/send-to-mqtt/
#
# https://docs.utilihive.io/utilihive-integration/send-to-rabbit-mq/
#
# https://docs.utilihive.io/utilihive-integration/set-exchange-property/
#
# https://docs.utilihive.io/utilihive-integration/set-payload/
#
# https://docs.utilihive.io/utilihive-integration/sign/
#
# https://docs.utilihive.io/utilihive-integration/soap-api/
#
# https://docs.utilihive.io/utilihive-integration/soap-request/
#
# https://docs.utilihive.io/utilihive-integration/split/
#
# https://docs.utilihive.io/utilihive-integration/suspend-message/
#
# https://docs.utilihive.io/utilihive-integration/to-base64/
#
# https://docs.utilihive.io/utilihive-integration/validate/
#
# https://docs.utilihive.io/utilihive-integration/verify-signature/
#
# https://docs.utilihive.io/utilihive-integration/windowed-aggregation-handoff/
#
# https://docs.utilihive.io/utilihive-integration/write-files/
#
# https://docs.utilihive.io/utilihive-integration/write-to-arrow/
#
# https://docs.utilihive.io/utilihive-integration/write-to-aws-s3/
#
# https://docs.utilihive.io/utilihive-integration/write-to-azure-blob-storage/
#
# https://docs.utilihive.io/utilihive-integration/write-to-google-storage/
#
# https://docs.utilihive.io/utilihive-integration/#amazon-web-services
#
# https://docs.utilihive.io/utilihive-integration/#archiving-and-resubmission
#
# https://docs.utilihive.io/utilihive-integration/#arrow
#
# https://docs.utilihive.io/utilihive-integration/#azure
#
# https://docs.utilihive.io/utilihive-integration/#copying
#
# https://docs.utilihive.io/utilihive-integration/#cryptography
#
# https://docs.utilihive.io/utilihive-integration/#databases
#
# https://docs.utilihive.io/utilihive-integration/#files
#
# https://docs.utilihive.io/utilihive-integration/#flat-files
#
# https://docs.utilihive.io/utilihive-integration/#google-cloud
#
# https://docs.utilihive.io/utilihive-integration/#internet
#
# https://docs.utilihive.io/utilihive-integration/#jms
#
# https://docs.utilihive.io/utilihive-integration/#kafka
#
# https://docs.utilihive.io/utilihive-integration/#mqtt
#
# https://docs.utilihive.io/utilihive-integration/#opc-ua
#
# https://docs.utilihive.io/utilihive-integration/#rabbitmq
#
# https://docs.utilihive.io/utilihive-integration/#routing-and-scheduling
#
# https://docs.utilihive.io/utilihive-integration/#scada
#
# https://docs.utilihive.io/utilihive-integration/#transformations
#
# https://docs.utilihive.io/utilihive-integration/#validation
#
# https://docs.utilihive.io/utilihive-integration/#sub-builders
#
# https://docs.utilihive.io/utilihive-integration/#details
#
# https://docs.utilihive.io/utilihive-integration/#fragment-handling
#
# https://docs.utilihive.io/utilihive-integration/#payload-conversion
#
# https://docs.utilihive.io/utilihive-integration/#formats
#
# https://docs.utilihive.io/utilihive-integration/#compression-strategy
#
# https://docs.utilihive.io/utilihive-integration/#authentication
#
# https://docs.utilihive.io/utilihive-integration/#input-format
#
# https://docs.utilihive.io/utilihive-integration/#output-format
#
# https://docs.utilihive.io/utilihive-integration/#filtering
#
# https://docs.utilihive.io/utilihive-integration/#results
#
# https://docs.utilihive.io/utilihive-integration/#handoff-syntax
#
# https://docs.utilihive.io/utilihive-integration/#expressions
#
# https://docs.utilihive.io/utilihive-integration/#modes
#
# https://docs.utilihive.io/utilihive-integration/#direct-grouping-key-lookup
#
# https://docs.utilihive.io/utilihive-integration/#sharding
#
# https://docs.utilihive.io/utilihive-integration/#expression-based-grouping-key-lookup
#
# https://docs.utilihive.io/utilihive-integration/#exchange-property
#
# https://docs.utilihive.io/utilihive-integration/#jsoniq-syntax
#
# https://docs.utilihive.io/utilihive-integration/#jsoniq-features
#
# https://docs.utilihive.io/utilihive-integration/#flow-data
#
# https://docs.utilihive.io/utilihive-integration/#exchange-properties
#
# https://docs.utilihive.io/utilihive-integration/#number-limits
#
# https://docs.utilihive.io/utilihive-integration/#utilihive-functions
#
# https://docs.utilihive.io/utilihive-integration/#_footnotedef_1
#
# https://docs.utilihive.io/utilihive-integration/#fail-function
#
# https://docs.utilihive.io/utilihive-integration/#datetime-functions
#
# https://docs.utilihive.io/utilihive-integration/#transform-coordinate-function
#
# https://docs.utilihive.io/utilihive-integration/#testing
#
# https://docs.utilihive.io/utilihive-integration/#unit-tests
#
# https://docs.utilihive.io/utilihive-integration/#functional-tests
#
# https://docs.utilihive.io/utilihive-integration/#_footnoteref_1
#
# https://docs.utilihive.io/utilihive-integration/#limitations
#
# https://docs.utilihive.io/utilihive-integration/#provider-types
#
# https://docs.utilihive.io/utilihive-integration/#tls-ssl-configuration
#
# https://docs.utilihive.io/utilihive-integration/#output-payload
#
# https://docs.utilihive.io/utilihive-integration/#client-key-store-usage
#
# https://docs.utilihive.io/utilihive-integration/#writing-testing-flows:guides/flow-traces/flow-traces.adoc
#
# https://docs.utilihive.io/utilihive-integration/#endpoints
#
# https://docs.utilihive.io/utilihive-integration/#schema-based-model
#
# https://docs.utilihive.io/utilihive-integration/#generic-model
#
# https://docs.utilihive.io/utilihive-integration/#responses
#
# https://docs.utilihive.io/utilihive-integration/#text-based-responses
#
# https://docs.utilihive.io/utilihive-integration/#binary-responses
#
# https://docs.utilihive.io/utilihive-integration/#supported-methods
#
# https://docs.utilihive.io/utilihive-integration/#Payload_Properties_As_Query_Parameters
#
# https://docs.utilihive.io/utilihive-integration/#before-processing
#
# https://docs.utilihive.io/utilihive-integration/#after-processing
#
# https://docs.utilihive.io/utilihive-integration/#implementation
#
# https://docs.utilihive.io/utilihive-integration/#payloads
#
# https://docs.utilihive.io/utilihive-integration/#retrieving-data
#
# https://docs.utilihive.io/utilihive-integration/#scope
#
# https://docs.utilihive.io/utilihive-integration/#schedule-format
#
# https://docs.utilihive.io/utilihive-integration/#payload
#
# https://docs.utilihive.io/utilihive-integration/#caveats
#
# https://docs.utilihive.io/utilihive-integration/#examples
#
# https://docs.utilihive.io/utilihive-integration/#config
#
# https://docs.utilihive.io/utilihive-integration/#wsdl-documents
#
# https://docs.utilihive.io/utilihive-integration/#ws-security-policy
#
# https://docs.utilihive.io/utilihive-integration/#ws-security-soap-message-security
#
# https://docs.utilihive.io/utilihive-integration/#ws-security-username-token-profile
#
# https://docs.utilihive.io/utilihive-integration/#validation-sources
#
# https://docs.utilihive.io/utilihive-integration/#message-processing
#
# https://docs.utilihive.io/utilihive-integration/#handoff-logging
#
# https://docs.utilihive.io/utilihive-integration/#server-shutdown
#
# https://docs.utilihive.io/utilihive-integration/#macos-linux
#
# https://docs.utilihive.io/utilihive-integration/#windows
#
# https://docs.utilihive.io/utilihive-integration/#json-compliant
#
# https://docs.utilihive.io/utilihive-integration/#xml-compliant
#
# https://docs.utilihive.io/utilihive-integration/#namespace-mapping
#
# https://docs.utilihive.io/utilihive-integration/#outbound-xml
#
# https://docs.utilihive.io/utilihive-integration/#strings
#
# https://docs.utilihive.io/utilihive-integration/#binary
#
# https://docs.utilihive.io/utilihive-integration/#binary-serialization
#
# https://docs.utilihive.io/utilihive-integration/#payload-conversions
#
# https://docs.utilihive.io/utilihive-integration/#avro-conversion
#
# https://docs.utilihive.io/utilihive-integration/#transformation-properties
#
# https://docs.utilihive.io/utilihive-integration/#types
#
# https://docs.utilihive.io/utilihive-integration/#arrow-schema-requirements
#
# https://docs.utilihive.io/utilihive-integration/#avro-schema-requirements
#
# https://docs.utilihive.io/utilihive-integration/#wsdlv1-requirements
#
# https://docs.utilihive.io/utilihive-integration/#dynamic-tables
#
# https://docs.utilihive.io/utilihive-integration/#limits
#
# https://docs.utilihive.io/utilihive-integration/#script-access
#
# https://docs.utilihive.io/utilihive-integration/#example-usage
#
# https://docs.utilihive.io/utilihive-integration/#patching
#
# https://docs.utilihive.io/utilihive-integration/#supported-types
#
# https://docs.utilihive.io/utilihive-integration/#apikey
#
# https://docs.utilihive.io/utilihive-integration/#apikeys
#
# https://docs.utilihive.io/utilihive-integration/#awscredentials
#
# https://docs.utilihive.io/utilihive-integration/#azureclientcertificate
#
# https://docs.utilihive.io/utilihive-integration/#azureconnectionstring
#
# https://docs.utilihive.io/utilihive-integration/#googleserviceaccountcredentials
#
# https://docs.utilihive.io/utilihive-integration/#oauth2
#
# https://docs.utilihive.io/utilihive-integration/#oauth2basic
#
# https://docs.utilihive.io/utilihive-integration/#oauth2password
#
# https://docs.utilihive.io/utilihive-integration/#oauth2signedjwt
#
# https://docs.utilihive.io/utilihive-integration/#signedjwt
#
# https://docs.utilihive.io/utilihive-integration/#sshprivatekey
#
# https://docs.utilihive.io/utilihive-integration/#tls
#
# https://docs.utilihive.io/utilihive-integration/#usernameandpassword
#
# https://docs.utilihive.io/utilihive-integration/#wsssignature
#
# https://docs.utilihive.io/utilihive-integration/#wssusernametoken
#
# https://docs.utilihive.io/utilihive-integration/#working-with-keystores
#
# https://docs.utilihive.io/utilihive-integration/#message-envelopes
#
# https://docs.utilihive.io/utilihive-integration/#metadata
#
# https://docs.utilihive.io/utilihive-integration/#stash
#
# https://docs.utilihive.io/utilihive-integration/#overview
#
# https://docs.utilihive.io/utilihive-integration/#expression-context
#
# https://docs.utilihive.io/utilihive-integration/#standard-expression-context
#
# https://docs.utilihive.io/utilihive-integration/#troubleshooting
#
# https://docs.utilihive.io/utilihive-integration/#variables
#
# https://docs.utilihive.io/utilihive-integration/#conditionals
#
# https://docs.utilihive.io/utilihive-integration/#functions
#
# https://docs.utilihive.io/utilihive-integration/#arrays-and-sequences
#
# https://docs.utilihive.io/utilihive-integration/#flwor-expressions
#
# https://docs.utilihive.io/utilihive-integration/#archiving-payloads
#
# https://docs.utilihive.io/utilihive-integration/#retrieving-payloads
#
# https://docs.utilihive.io/utilihive-integration/#resubmitting-payloads
#
# https://docs.utilihive.io/utilihive-integration/#setting-up-the-flows
#
# https://docs.utilihive.io/utilihive-integration/#example-message-generator
#
# https://docs.utilihive.io/utilihive-integration/#envelopes-as-payloads
#
# https://docs.utilihive.io/utilihive-integration/#merging-wsdl-files
#
# https://docs.utilihive.io/utilihive-integration/#fields
#
# https://docs.utilihive.io/utilihive-integration/#null
#
# https://docs.utilihive.io/utilihive-integration/#utf8
#
# https://docs.utilihive.io/utilihive-integration/#largeutf8
#
# https://docs.utilihive.io/utilihive-integration/#largebinary
#
# https://docs.utilihive.io/utilihive-integration/#bool
#
# https://docs.utilihive.io/utilihive-integration/#int
#
# https://docs.utilihive.io/utilihive-integration/#floatingpoint
#
# https://docs.utilihive.io/utilihive-integration/#fixedsizebinary
#
# https://docs.utilihive.io/utilihive-integration/#decimal
#
# https://docs.utilihive.io/utilihive-integration/#date
#
# https://docs.utilihive.io/utilihive-integration/#time
#
# https://docs.utilihive.io/utilihive-integration/#timestamp
#
# https://docs.utilihive.io/utilihive-integration/#duration
#
# https://docs.utilihive.io/utilihive-integration/#primitive-types
#
# https://docs.utilihive.io/utilihive-integration/#complex-types
#
# https://docs.utilihive.io/utilihive-integration/#avro-schema-example
#
# https://docs.utilihive.io/utilihive-integration/deployer/
#
# https://docs.utilihive.io/utilihive-integration/advanced/
#
# https://docs.utilihive.io/utilihive-integration/on-prem-flow-server/
#
# https://docs.utilihive.io/utilihive-integration/management-api/
#
# https://docs.utilihive.io/utilihive-integration/heartbeat/
#
# https://docs.utilihive.io/utilihive-integration/flow-access/
#
# https://docs.utilihive.io/utilihive-integration/#configuration
#
# https://docs.utilihive.io/utilihive-integration/#required-parameters
#
# https://docs.utilihive.io/utilihive-integration/#authentication-related-parameters
#
# https://docs.utilihive.io/utilihive-integration/#oauth2-with-password-grant
#
# https://docs.utilihive.io/utilihive-integration/#oauth2-with-code-grant
#
# https://docs.utilihive.io/utilihive-integration/#oauth2-with-client-credential-grant
#
# https://docs.utilihive.io/utilihive-integration/#optional-parameters
#
# https://docs.utilihive.io/utilihive-integration/#Untrusted_Server_Certificate
#
# https://docs.utilihive.io/utilihive-integration/#management_api_root
#
# https://docs.utilihive.io/utilihive-integration/#identity_api_root
#
# https://docs.utilihive.io/utilihive-integration/#token_endpoint1
#
# https://docs.utilihive.io/utilihive-integration/#token_endpoint2
#
# https://docs.utilihive.io/utilihive-integration/#tls_certificate_authority_pem
#
# https://docs.utilihive.io/utilihive-integration/#directory-layout
#
# https://docs.utilihive.io/utilihive-integration/#deployer-properties
#
# https://docs.utilihive.io/utilihive-integration/#flow-access
#
# https://docs.utilihive.io/utilihive-integration/#deployment-types
#
# https://docs.utilihive.io/utilihive-integration/#flow-specs
#
# https://docs.utilihive.io/utilihive-integration/#flow-deplyment-context
#
# https://docs.utilihive.io/utilihive-integration/#deployment-configurations
#
# https://docs.utilihive.io/utilihive-integration/#fallback-properties
#
# https://docs.utilihive.io/utilihive-integration/#deleting-entities
#
# https://docs.utilihive.io/utilihive-integration/#programmatic-configuration
#
# https://docs.utilihive.io/utilihive-integration/#file-system-mode
#
# https://docs.utilihive.io/utilihive-integration/#diff-reports
#
# https://docs.utilihive.io/utilihive-integration/#flows-and-resources
#
# https://docs.utilihive.io/utilihive-integration/#bundles
#
# https://docs.utilihive.io/utilihive-integration/#flows
#
# https://docs.utilihive.io/utilihive-integration/#command-files
#
# https://docs.utilihive.io/utilihive-integration/#resources-and-secrets
#
# https://docs.utilihive.io/utilihive-integration/#access
#
# https://docs.utilihive.io/utilihive-integration/#documentation
#
# https://docs.utilihive.io/utilihive-integration/#flow-apis
#
# https://docs.utilihive.io/utilihive-integration/#resource-registry-apis
#
# https://docs.utilihive.io/utilihive-integration/#pausing-flows
#
# https://docs.utilihive.io/utilihive-integration/#managing-resources
#
# https://docs.utilihive.io/utilihive-integration/#creating-a-service-account
#
# https://docs.utilihive.io/utilihive-integration/#credential-types
#
# https://docs.utilihive.io/utilihive-integration/#granting-access-to-flows
#
# https://docs.utilihive.io/utilihive-integration/users/
#
# https://docs.utilihive.io/utilihive-integration/audits/
#
# https://docs.utilihive.io/utilihive-integration/beatbox/
#
# https://docs.utilihive.io/utilihive-integration/#viewing-users
#
# https://docs.utilihive.io/utilihive-integration/#creating-a-user
#
# https://docs.utilihive.io/utilihive-integration/#user-roles
#
# https://docs.utilihive.io/utilihive-integration/#updating-user-roles
#
# https://docs.utilihive.io/utilihive-integration/#system-requirements
#
# https://docs.utilihive.io/utilihive-integration/#creating-an-id
#
# https://docs.utilihive.io/utilihive-integration/#installing-beatbox
#
# https://docs.utilihive.io/utilihive-integration/#managing-beatbox
#
# https://docs.utilihive.io/utilihive-integration/flow-list/
#
# https://docs.utilihive.io/utilihive-integration/flow-details/
#
# https://docs.utilihive.io/utilihive-integration/flow-traces/
#
# https://docs.utilihive.io/utilihive-integration/alerts/
#
# https://docs.utilihive.io/utilihive-integration/reporting/
#
# https://docs.utilihive.io/utilihive-integration/#message-statuses
#
# https://docs.utilihive.io/utilihive-integration/#time-range
#
# https://docs.utilihive.io/utilihive-integration/#flow-spec
#
# https://docs.utilihive.io/utilihive-integration/#downloading-traces
#
# https://docs.utilihive.io/utilihive-integration/#inspecting-failed-messages
#
# https://docs.utilihive.io/utilihive-integration/#resubmitting-messages
#
# https://docs.utilihive.io/utilihive-integration/#batch-resubmits
#
# https://docs.utilihive.io/utilihive-integration/#global-reporting
#
# https://docs.utilihive.io/utilihive-integration/#flow-level-reporting
#
# https://docs.utilihive.io/utilihive-integration/#concept
#
# https://docs.utilihive.io/utilihive-integration/#capabilities
#
# https://docs.utilihive.io/utilihive-integration/#base-data-structure-for-time-series
#
# https://docs.utilihive.io/utilihive-integration/#derived-data-structures-and-observation-types
#
# https://docs.utilihive.io/utilihive-integration/#domain-models
#
# https://docs.utilihive.io/utilihive-integration/#main-http-api
#
# https://docs.utilihive.io/utilihive-integration/#graphql-api
#
# https://docs.utilihive.io/utilihive-integration/#authentication-2
#
# https://docs.utilihive.io/utilihive-integration/#authorization
#
# https://docs.utilihive.io/utilihive-integration/#source-compositions
#
# https://docs.utilihive.io/utilihive-integration/#datalake-flows
#
# https://docs.utilihive.io/utilihive-integration/#previous-datalake-api-versions
#
# https://docs.utilihive.io/utilihive-integration/#mapping-of-legacy-cim-messages
#
# https://docs.utilihive.io/utilihive-integration/writing-testing-flows/processors/map/#utilihive-functions
#
# https://docs.utilihive.io/utilihive-integration/#cim-rdfxml-api
#
# https://docs.utilihive.io/utilihive-integration/#fullmodel-flow
#
# https://docs.utilihive.io/utilihive-integration/#differencemodel-flow
#
# https://docs.utilihive.io/utilihive-integration/persistence.html#nulled-states
#
# https://docs.utilihive.io/utilihive-integration/#payload-types
#
# https://docs.utilihive.io/utilihive-integration/#cloudevents-extensions
#
# https://docs.utilihive.io/utilihive-integration/#dataref-extension
#
# https://docs.utilihive.io/utilihive-integration/#object-store
#
# https://docs.utilihive.io/utilihive-integration/#tabular-storage
#
# https://docs.utilihive.io/utilihive-integration/#time-series-state-tables
#
# https://docs.utilihive.io/utilihive-integration/#history-of-all-data-mutations
#
# https://docs.utilihive.io/utilihive-integration/#message-index
#
# https://docs.utilihive.io/utilihive-integration/#deletes
#
# https://docs.utilihive.io/utilihive-integration/#nulled-states
#
# https://docs.utilihive.io/utilihive-integration/#data-lifecycles
#
# https://docs.utilihive.io/utilihive-integration/#schema
#
# https://docs.utilihive.io/utilihive-integration/#replication
#
# https://docs.utilihive.io/utilihive-integration/#schema-management
#
# https://docs.utilihive.io/utilihive-integration/#user-schemas-and-auxiliary-data
#
# https://docs.utilihive.io/utilihive-integration/#integration
#
# https://docs.utilihive.io/utilihive-integration/#odbc
#
# https://docs.utilihive.io/utilihive-integration/#jdbc
#
# https://docs.utilihive.io/utilihive-integration/#python-language
#
# https://docs.utilihive.io/utilihive-integration/#r-language
#
# https://docs.utilihive.io/utilihive-integration/#other-languages
#
# https://docs.utilihive.io/utilihive-integration/#superset
#
# https://docs.utilihive.io/utilihive-integration/#authentication-and-authorization
#
# https://docs.utilihive.io/utilihive-integration/#jupyterhub
#
# https://docs.utilihive.io/utilihive-integration/#workspace-persistence
#
# https://docs.utilihive.io/utilihive-integration/#creating-a-simulation
#
# https://docs.utilihive.io/utilihive-integration/#managing-simulations
#
# https://docs.utilihive.io/utilihive-integration/#usage-points
#
# https://docs.utilihive.io/utilihive-integration/#events

# %%
pages[0]
# Out:
# {'url': 'https://docs.utilihive.io/utilihive-integration/',
#  'text': 'Utilihive Integration\nLearn about Utilihive\n-\nSee what’s available in the Utilihive platform.\nStart Developing\n-\nGet up and running with the tools to write flow configurations.\n-\nJump into the detailed developer guides.\n-\nReady to deploy a flow? Try the SDK Deployer.\nExplore the Console\n-\nMonitor your data with Heartbeat.\n-\nUtility-specific needs? Check out the Utilihive Accelerators like Datalake and Ghostwriter.'}
